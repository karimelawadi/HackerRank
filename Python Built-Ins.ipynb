# %% [markdown]
# Python Built-Ins Zipped!

# %%
n, x = map(int, input().split())
subjects = []
for _ in range(x):
    subjects.append(list(map(float, input().split())))

for student_scores in zip(*subjects):
    print(round(sum(student_scores) / x, 1))

# %% [markdown]
# Python Built-Ins Input()

# %%
x, k = map(int, input().split())
P = input()
print(k == eval(P))
